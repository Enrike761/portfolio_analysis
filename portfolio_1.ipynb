# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("asset_price_data.csv")

# %%
df.index += 1

# %%
df
# Out:
#            date    Asset1   Asset2     Asset3  Asset4  Asset5
# 1    2019-01-02  231.5061   55.875  25.649222  302.93   50.89
# 2    2019-01-03  231.0356   54.977  25.503047  302.11   50.41
# 3    2019-01-04  230.4026   56.129  26.147133  301.77   51.38
# 4    2019-01-07  230.0543   56.838  25.955277  302.33   52.14
# 5    2019-01-08  229.7012   56.895  26.137997  303.42   52.13
# ..          ...       ...      ...        ...     ...     ...
# 779  2021-12-27  249.9207  103.956  38.820000     NaN   70.11
# 780  2021-12-28  249.9368  104.526  39.115000     NaN   70.03
# 781  2021-12-29  248.7215  104.360  38.855000  342.46   69.81
# 782  2021-12-30  248.5485  104.663  38.985000  342.55   69.91
# 783  2021-12-31  248.7545  104.106  39.005000  342.59     NaN
#
# [783 rows x 6 columns]

# %%
df.describe()
# Out:
#            Asset1      Asset2      Asset3      Asset4      Asset5
# count  770.000000  770.000000  770.000000  734.000000  763.000000
# mean   248.980188   76.112381   31.473296  327.356880   54.123198
# std      6.845006   13.642823    3.304415   13.487611    8.185047
# min    229.701200   48.516000   22.895066  272.790000   37.340000
# 25%    246.868050   64.786250   29.281948  318.765000   49.120000
# 50%    250.685350   72.003000   30.651198  326.665000   52.720000
# 75%    253.379275   88.973000   33.757265  340.155000   59.500000
# max    259.110000  104.663000   39.115000  345.710000   71.050000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 1 to 783
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    783 non-null    object
#  1   Asset1  770 non-null    float64
#  2   Asset2  770 non-null    float64
#  3   Asset3  770 non-null    float64
#  4   Asset4  734 non-null    float64
#  5   Asset5  763 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 36.8+ KB

# %%
missing_values_per_column = df.isna().sum()

# %%
missing_values_per_column
# Out:
# date       0
# Asset1    13
# Asset2    13
# Asset3    13
# Asset4    49
# Asset5    20
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 1 to 783
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    783 non-null    datetime64[ns]
#  1   Asset1  770 non-null    float64
#  2   Asset2  770 non-null    float64
#  3   Asset3  770 non-null    float64
#  4   Asset4  734 non-null    float64
#  5   Asset5  763 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 36.8 KB

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Asset1'], color='blue', label='Asset')
plt.title('Time Series of Asset1')
plt.xlabel('Time')
plt.ylabel('Asset1')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Asset2'], color='blue', label='Asset')
plt.title('Time Series of Asset2')
plt.xlabel('Time')
plt.ylabel('Asset2')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Asset3'], color='blue', label='Asset')
plt.title('Time Series of Asset3')
plt.xlabel('Time')
plt.ylabel('Asset3')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Asset4'], color='blue', label='Asset')
plt.title('Time Series of Asset4')
plt.xlabel('Time')
plt.ylabel('Asset4')
plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Asset5'], color='blue', label='Asset')
plt.title('Time Series of Asset5')
plt.xlabel('Time')
plt.ylabel('Asset5')
plt.legend()

# %% [markdown]
# #Exercise2

# %%
df.fillna(method='ffill', inplace=True) #rellenamos los Nan con los valores próximos para poder calcular los retornos porcentuales diarios
# Out:
# C:\Users\enrik\AppData\Local\Temp\ipykernel_50380\867595811.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True) #rellenamos los Nan con los valores próximos para poder calcular los retornos porcentuales diarios

# %%
df.isna().sum()
# Out:
# date      0
# Asset1    0
# Asset2    0
# Asset3    0
# Asset4    0
# Asset5    0
# dtype: int64

# %%
df
# Out:
#           date    Asset1   Asset2     Asset3  Asset4  Asset5
# 1   2019-01-02  231.5061   55.875  25.649222  302.93   50.89
# 2   2019-01-03  231.0356   54.977  25.503047  302.11   50.41
# 3   2019-01-04  230.4026   56.129  26.147133  301.77   51.38
# 4   2019-01-07  230.0543   56.838  25.955277  302.33   52.14
# 5   2019-01-08  229.7012   56.895  26.137997  303.42   52.13
# ..         ...       ...      ...        ...     ...     ...
# 779 2021-12-27  249.9207  103.956  38.820000  342.40   70.11
# 780 2021-12-28  249.9368  104.526  39.115000  342.40   70.03
# 781 2021-12-29  248.7215  104.360  38.855000  342.46   69.81
# 782 2021-12-30  248.5485  104.663  38.985000  342.55   69.91
# 783 2021-12-31  248.7545  104.106  39.005000  342.59   69.91
#
# [783 rows x 6 columns]

# %%
df.set_index('date', inplace=True) #convertimos date en índice para calcular los porcentajes

# %%
returns = df.pct_change() #Calcula la variación porcentual entre los valores de cada fila y la anterior. El resultado será un DataFrame con los retornos porcentuales diarios.

# %%
returns
# Out:
#               Asset1    Asset2    Asset3    Asset4    Asset5
# date
# 2019-01-02       NaN       NaN       NaN       NaN       NaN
# 2019-01-03 -0.002032 -0.016072 -0.005699 -0.002707 -0.009432
# 2019-01-04 -0.002740  0.020954  0.025255 -0.001125  0.019242
# 2019-01-07 -0.001512  0.012632 -0.007338  0.001856  0.014792
# 2019-01-08 -0.001535  0.001003  0.007040  0.003605 -0.000192
# ...              ...       ...       ...       ...       ...
# 2021-12-27 -0.000913  0.007384  0.005439  0.000000  0.013443
# 2021-12-28  0.000064  0.005483  0.007599  0.000000 -0.001141
# 2021-12-29 -0.004862 -0.001588 -0.006647  0.000175 -0.003142
# 2021-12-30 -0.000696  0.002903  0.003346  0.000263  0.001432
# 2021-12-31  0.000829 -0.005322  0.000513  0.000117  0.000000
#
# [783 rows x 5 columns]

# %%
#en la primera columna son Nans al no poder calcular el porcentaje por no tener comparativa

# %%
correlation_matrix = returns.corr()

# %%
correlation_matrix
# Out:
#           Asset1    Asset2    Asset3    Asset4    Asset5
# Asset1  1.000000 -0.088341 -0.061253  0.102252 -0.106484
# Asset2 -0.088341  1.000000  0.852491  0.526634  0.591399
# Asset3 -0.061253  0.852491  1.000000  0.511550  0.557414
# Asset4  0.102252  0.526634  0.511550  1.000000  0.421155
# Asset5 -0.106484  0.591399  0.557414  0.421155  1.000000

# %%
#podemos observar una correlación neutra en Asset1 respecto al resto (primera columna), es decir, los distintos activos siguen una dirección random ya que la correlación es cercana al 0, siendo 1 una dirección homogénea perfecta y -1 opuesta

# %%
plt.scatter(returns["Asset1"], returns["Asset2"], color='blue')

# %%
plt.scatter(returns["Asset3"], returns["Asset5"], color='green')

# %%
#en los gráficos no observamos una correlación fuerte, y el segundo gráfico muestra una mayor correlación entre asset3 y 5 que los assets 1 y 2

# %% [markdown]
# #Exercise3

# %%
dfw = pd.read_csv("portfolio_weights.csv")

# %%
dfw
# Out:
#            date    Asset1    Asset2    Asset3   Asset4    Asset5
# 0    2019-01-02  0.225458  0.116255  0.265003  0.23031  0.162974
# 1    2019-01-03  0.225458  0.116255  0.265003  0.23031  0.162974
# 2    2019-01-04  0.225458  0.116255  0.265003  0.23031  0.162974
# 3    2019-01-07  0.225458  0.116255  0.265003  0.23031  0.162974
# 4    2019-01-08  0.225458  0.116255  0.265003  0.23031  0.162974
# ..          ...       ...       ...       ...      ...       ...
# 778  2021-12-27  0.071307  0.266093  0.168775  0.33547  0.158356
# 779  2021-12-28  0.071307  0.266093  0.168775  0.33547  0.158356
# 780  2021-12-29  0.071307  0.266093  0.168775  0.33547  0.158356
# 781  2021-12-30  0.071307  0.266093  0.168775  0.33547  0.158356
# 782  2021-12-31  0.071307  0.266093  0.168775  0.33547  0.158356
#
# [783 rows x 6 columns]

# %%
dfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    783 non-null    object
#  1   Asset1  783 non-null    float64
#  2   Asset2  783 non-null    float64
#  3   Asset3  783 non-null    float64
#  4   Asset4  783 non-null    float64
#  5   Asset5  783 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 36.8+ KB

# %%
dfw.index +=1

# %%
dfw
# Out:
#            date    Asset1    Asset2    Asset3   Asset4    Asset5
# 1    2019-01-02  0.225458  0.116255  0.265003  0.23031  0.162974
# 2    2019-01-03  0.225458  0.116255  0.265003  0.23031  0.162974
# 3    2019-01-04  0.225458  0.116255  0.265003  0.23031  0.162974
# 4    2019-01-07  0.225458  0.116255  0.265003  0.23031  0.162974
# 5    2019-01-08  0.225458  0.116255  0.265003  0.23031  0.162974
# ..          ...       ...       ...       ...      ...       ...
# 779  2021-12-27  0.071307  0.266093  0.168775  0.33547  0.158356
# 780  2021-12-28  0.071307  0.266093  0.168775  0.33547  0.158356
# 781  2021-12-29  0.071307  0.266093  0.168775  0.33547  0.158356
# 782  2021-12-30  0.071307  0.266093  0.168775  0.33547  0.158356
# 783  2021-12-31  0.071307  0.266093  0.168775  0.33547  0.158356
#
# [783 rows x 6 columns]

# %%
dfw.set_index('date', inplace=True)

# %%
dfw.plot.area(stacked=True, figsize=(10, 6))

plt.title('Daily Asset Weights Over Time')
plt.xlabel('Date')
plt.ylabel('Weight (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
